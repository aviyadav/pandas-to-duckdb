# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/MrBeast_youtube_stats.csv')

# %%
df.groupby('id')['title'].nunique().sort_values(ascending=False) #.head(50)
# Out:
# id
# 0CTp1a-aCUM    5
# 65fN_OUawjk    4
# 2isYuQZMbdU    4
# vBpQ1SlfVtU    4
# hTSaweR8qMI    3
#               ..
# MFpWEKN9c6Y    1
# MLN6TRB9Jxw    1
# MOGW3v3pJ5Y    1
# MUQCwdkEbq0    1
# LdMx2U5tby0    1
# Name: title, Length: 942, dtype: int64

# %%
df['pull_date'] = pd.to_datetime(df['pull_date'])

# %%
df['pull_date'].value_counts().sort_index().plot(style='.',
                                                title='Number of Videos pulled per day')
# Out:
# <Axes: title={'center': 'Number of Videos pulled per day'}, xlabel='pull_date'>

# %%
df = df.dropna(subset='viewCount').reset_index(drop=True)
df['viewCount'] = df['viewCount'].astype('int')

# %%
df.groupby(['id','title'])[['viewCount','pull_date']] \
        .max() \
        .reset_index() \
        .sort_values('viewCount')
# Out:
#                id                                          title   viewCount  \
# 248   F3fmzCmIJ14  This Stream Ends When Someone Wins $1,000,000           0
# 478   TGKkMl17Htg              Battle Pirates, Unstoppable Ship!       35956
# 1011  ywZy_Fo2ydo                           Modern Art Is A Joke       36613
# 930   u6t4jrhs56Q              Top Youtube &quot;ShoutOuts&quot;       36633
# 113   6T17licWsQ4                             Leaving For 7 Days       39197
# ...           ...                                            ...         ...
# 23    0e3GPea1Tyg              $456,000 Squid Game In Real Life!   912902741
# 342   L5kIXRdwGAI                               Katana Vs Bullet  1085305868
# 290   IQxea9UB1nQ                         $100,000,000 Car Doors  1186290758
# 568   YlvcFJOE-OE   Giving iPhones Instead Of Candy on Halloween  1585806289
# 896   se50viFJ0AQ         Would You Fly To Paris For A Baguette?  1639754975
#
#                             pull_date
# 248  2026-04-05 00:06:18.400542+00:00
# 478  2023-08-07 00:09:55.117235+00:00
# 1011 2023-08-27 00:12:06.324381+00:00
# 930  2023-08-27 00:12:06.324381+00:00
# 113  2023-07-24 00:13:41.788641+00:00
# ...                               ...
# 23   2026-03-16 00:05:43.552049+00:00
# 342  2025-10-18 00:02:51.349756+00:00
# 290  2025-08-18 00:04:33.009006+00:00
# 568  2025-11-16 00:05:42.110033+00:00
# 896  2025-12-04 00:03:43.943084+00:00
#
# [1036 rows x 4 columns]

# %%
video_name = df.query('id == "se50viFJ0AQ"')['title'].values[0]
fig, ax = plt.subplots(figsize=(12, 5))
ax2 = ax.twinx()
df.query('id == "se50viFJ0AQ"').set_index('pull_date')['viewCount'].plot(
    ax=ax,
    title=f'Likes and Views over time for "{video_name}"')
df.query('id == "se50viFJ0AQ"').set_index('pull_date')['likeCount'].plot(ax=ax2, color='red')
# Out:
# <Axes: xlabel='pull_date'>

# %%
df = pd.read_parquet('data/MrBeast_youtube_stats_processed.parquet')

# %%
df['like_to_view_ratio'] = df['like_diff'] / df['view_diff']

# %%
df.query('view_diff != 0') \
        .sort_values('like_to_view_ratio', ascending=False)
# Out:
#                  id                                             title  \
https://i.ytimg.com/vi/zxuICI0kL3s/default.jpg  ...
#
#         snippet.defaultLanguage                localizations.en.title  \
# 191688                      NaN                                   NaN
# 191710                      NaN                                   NaN
# 126074                       en  I Donated $300,000 To People In Need
# 148565                       en  I Donated $300,000 To People In Need
# 135275                       en  I Donated $300,000 To People In Need
# ...                         ...                                   ...
# 436343                      NaN                                   NaN
# 85657                        en     I Got T-Series To Subscribe To Me
# 419129                      NaN                                   NaN
# 454516                      NaN                                   NaN
# 13120                        en           Don’t Turn Around, Win $10k
#
#                              localizations.en.description  \
# 191688                                                NaN
# 191710                                                NaN
# 126074  Subscribe and I'll Donate $0.10 To Charity\n\n...
# 148565  Subscribe and I'll Donate $0.10 To Charity\n\n...
# 135275  Subscribe and I'll Donate $0.10 To Charity\n\n...
# ...                                                   ...
# 436343                                                NaN
# 85657                                                 NaN
# 419129                                                NaN
# 454516                                                NaN
# 13120                                                 NaN
#
#                                              snippet.tags  \
# 191688                  ['tipping pizza guys', 'tipping']
# 191710      ['Giving mom 100000', 'giving my mom', 'mom']
# 126074                                                NaN
# 148565                                                NaN
# 135275                                                NaN
# ...                                                   ...
# 436343  ['Mr.Beast', 'mr', 'beast', 'thanks', 'for', '...
# 85657                                                 NaN
# 419129  ['How', 'much', 'money', 'does', 'make', 'blac...
# 454516                                                NaN
# 13120                                                 NaN
#
#                               pull_date   time_since_last_pull  view_diff  \
# 191688 2024-05-08 00:10:49.880176+00:00 1 days 00:00:34.141142      309.0
# 191710 2024-05-08 00:10:49.880176+00:00 1 days 00:00:34.141142     1021.0
# 126074 2024-09-21 00:07:46.820812+00:00 2 days 00:04:46.558049       -1.0
# 148565 2024-08-05 00:06:32.183949+00:00 0 days 23:56:07.619352       -1.0
# 135275 2024-09-01 00:06:15.728579+00:00 0 days 23:56:12.239023       -5.0
# ...                                 ...                    ...        ...
# 436343 2022-03-11 02:12:02.295306+00:00                    NaT        NaN
# 85657  2024-12-10 00:04:34.161738+00:00                    NaT        NaN
# 419129 2022-08-29 00:30:32.501034+00:00                    NaT        NaN
# 454516 2021-12-24 01:41:03.667334+00:00                    NaT        NaN
# 13120  2025-08-01 00:10:16.484770+00:00                    NaT        NaN
#
#         like_diff comment_diff like_to_view_ratio
# 191688   695773.0      40855.0        2251.692557
# 191710  1529468.0      44545.0        1498.009794
# 126074     -167.0        -44.0         167.000000
# 148565     -164.0        -70.0         164.000000
# 135275     -393.0         -8.0          78.600000
# ...           ...          ...                ...
# 436343        NaN          NaN                NaN
# 85657         NaN          NaN                NaN
# 419129        NaN          NaN                NaN
# 454516        NaN          NaN                NaN
# 13120         NaN          NaN                NaN
#
# [427015 rows x 31 columns]

# %%
df.query('id == "uotb9ZHnI2g"').set_index('pull_date')['like_to_view_ratio'].plot(figsize=(15, 5))
# Out:
# <Axes: xlabel='pull_date'>

# %%
df['view_diff_norm'] = df['view_diff'] / (df['time_since_last_pull'].dt.total_seconds() / (60 * 60 * 12))

# %%
df['like_diff_norm'] = df['like_diff'] / (df['time_since_last_pull'].dt.total_seconds() / (60 * 60 * 12))

# %%
random_vids = df['id'].sample(10, random_state=529).values

for v in random_vids:
    title = df.query('id == @v')['title'].values[0]
    df.query('id == @v').sort_values('pull_date') \
            .set_index('pull_date')[['view_diff_norm','like_diff_norm']].plot(figsize=(15, 5),
                                                       title=title)

# %% [markdown]
# ## Look at videos with crazy ratios

# %%
df['like_ratio_norm'] = df['like_diff_norm'] / df['view_diff_norm']

# %%
top_10 = df.query('like_ratio_norm <= 1') \
        .query('view_diff_norm != 0') \
        .groupby('title')['like_ratio_norm'] \
        .max().sort_values(ascending=False)

# %%
top_10
# Out:
# title
# Why Do Youtubers Ask For Likes?                           1.000000
# 5$ To Advertise Your Youtube Channel???                   1.000000
# How To Become A Gaming Youtuber! All You Need To Know!    1.000000
# How Many People Get The Diamond Play Button?????          1.000000
# Free To Use Advanced Warfare Gameplay! 2015               1.000000
#                                                             ...
# World&#39;s Biggest YouTubers Fight for $1,000,000       -0.000384
# Get Every Boy Scout Badge, Win $10,000                   -0.006398
# Making Fun Of Youtuber&#39;s Intros.                     -0.013158
# Every Challenge I&#39;ve Ever Done                       -0.017544
# IF ONLINE ADS WERE REAL                                  -0.177040
# Name: like_ratio_norm, Length: 986, dtype: float64

# %%
top_10 = df.query('like_ratio_norm <= 1') \
        .query('view_diff_norm != 0') \
        .groupby('id')['like_ratio_norm'] \
        .max().sort_values(ascending=False).index.values[:10]
for v in top_10:
    title = df.query('id == @v')['title'].values[0]
    df.query('id == @v').sort_values('pull_date') \
            .set_index('pull_date')[['view_diff_norm','like_diff_norm']].plot(figsize=(15, 5),
                                                       title=title)

# %%
df.query('id == "se50viFJ0AQ"')[['viewCount','likeCount']].corr()
# Out:
#            viewCount  likeCount
# viewCount   1.000000   0.992915
# likeCount   0.992915   1.000000

# %%
pd.set_option('display.max_columns', 50) 
df
# Out:
#                  id                                            title  \
# 454695  -0zoWMSEOGg  I Gave My 6,000,000th Subscriber 6,000,000 ____
# 454448  -0zoWMSEOGg  I Gave My 6,000,000th Subscriber 6,000,000 ____
# 454207  -0zoWMSEOGg  I Gave My 6,000,000th Subscriber 6,000,000 ____
# 453955  -0zoWMSEOGg  I Gave My 6,000,000th Subscriber 6,000,000 ____
# 453707  -0zoWMSEOGg  I Gave My 6,000,000th Subscriber 6,000,000 ____
# ...             ...                                              ...
# 12652   zxuICI0kL3s                      Don’t Turn Around, Win $10k
# 12518   zxuICI0kL3s                      Don’t Turn Around, Win $10k
# 12406   zxuICI0kL3s                      Don’t Turn Around, Win $10k
# 12299   zxuICI0kL3s                      Don’t Turn Around, Win $10k
# 12208   zxuICI0kL3s                      Don’t Turn Around, Win $10k
#
#                                               description  \
# 454695  YOU WON'T BELIEVE WHAT WE GAVE HIM Best Shirts...
# 454448  YOU WON'T BELIEVE WHAT WE GAVE HIM Best Shirts...
# 454207  YOU WON'T BELIEVE WHAT WE GAVE HIM Best Shirts...
# 453955  YOU WON'T BELIEVE WHAT WE GAVE HIM Best Shirts...
#
#         thumbnails.medium.width  thumbnails.medium.height  \
# 454695                    320.0                     180.0
# 454448                    320.0                     180.0
# 454207                    320.0                     180.0
# 453955                    320.0                     180.0
# 453707                    320.0                     180.0
# ...                         ...                       ...
# 12652                     320.0                     180.0
# 12518                     320.0                     180.0
# 12406                     320.0                     180.0
# 12299                     320.0                     180.0
# 12208                     320.0                     180.0
#
#                                      thumbnails.high.url  \
# 454695  https://i.ytimg.com/vi/-0zoWMSEOGg/hqdefault.jpg
# 454448  https://i.ytimg.com/vi/-0zoWMSEOGg/hqdefault.jpg
# 454207  https://i.ytimg.com/vi/-0zoWMSEOGg/hqdefault.jpg
# 453955  https://i.ytimg.com/vi/-0zoWMSEOGg/hqdefault.jpg
# 453707  https://i.ytimg.com/vi/-0zoWMSEOGg/hqdefault.jpg
# ...                                                  ...
# 12652   https://i.ytimg.com/vi/zxuICI0kL3s/hqdefault.jpg
# 12518   https://i.ytimg.com/vi/zxuICI0kL3s/hqdefault.jpg
# 12406   https://i.ytimg.com/vi/zxuICI0kL3s/hqdefault.jpg
# 12299   https://i.ytimg.com/vi/zxuICI0kL3s/hqdefault.jpg
# 12208   https://i.ytimg.com/vi/zxuICI0kL3s/hqdefault.jpg
#
#         thumbnails.high.width  thumbnails.high.height contentDetails.duration  \
# 454695                  480.0                   360.0                PT18M33S
# 454448                  480.0                   360.0                PT18M33S
# 454207                  480.0                   360.0                PT18M33S
# 453955                  480.0                   360.0                PT18M33S
# 453707                  480.0                   360.0                PT18M33S
# ...                       ...                     ...                     ...
# 12652                   480.0                   360.0                   PT31S
# 12518                   480.0                   360.0                   PT31S
# 12406                   480.0                   360.0                   PT31S
# 12299                   480.0                   360.0                   PT31S
# 12208                   480.0                   360.0                   PT31S
#
#        contentDetails.dimension  \
# 454695                       2d
# 454448                       2d
# 454207                       2d
# 453955                       2d
# 453707                       2d
# ...                         ...
# 12652                        2d
# 12518                        2d
# 12406                        2d
# 12299                        2d
# 12208                        2d
#
#                              topicDetails.topicCategories  \
# 454695  ['https://en.wikipedia.org/wiki/Action-adventu...
# 454448  ['https://en.wikipedia.org/wiki/Action-adventu...
# 454207  ['https://en.wikipedia.org/wiki/Action-adventu...
# 453955  ['https://en.wikipedia.org/wiki/Action-adventu...
# 453707  ['https://en.wikipedia.org/wiki/Action-adventu...
# ...                                                   ...
# 12652     ['https://en.wikipedia.org/wiki/Entertainment']
# 12518     ['https://en.wikipedia.org/wiki/Entertainment']
# 12406     ['https://en.wikipedia.org/wiki/Entertainment']
# 12299     ['https://en.wikipedia.org/wiki/Entertainment']
# 12208     ['https://en.wikipedia.org/wiki/Entertainment']
#
#        snippet.defaultLanguage       localizations.en.title  \
# 454695                     NaN                          NaN
# 454448                     NaN                          NaN
# 454207                     NaN                          NaN
# 453955                     NaN                          NaN
# 453707                     NaN                          NaN
# ...                        ...                          ...
# 12652                       en  Don’t Turn Around, Win $10k
# 12518                       en  Don’t Turn Around, Win $10k
# 12406                       en  Don’t Turn Around, Win $10k
# 12299                       en  Don’t Turn Around, Win $10k
# 12208                       en  Don’t Turn Around, Win $10k
#
#        localizations.en.description snippet.tags  \
# 454695                          NaN          NaN
# 454448                          NaN          NaN
# 454207                          NaN          NaN
# 453955                          NaN          NaN
# 453707                          NaN          NaN
# ...                             ...          ...
# 12652                           NaN          NaN
# 12518                           NaN          NaN
# 12406                           NaN          NaN
# 12299                           NaN          NaN
# 12208                           NaN          NaN
#
#                               pull_date   time_since_last_pull   view_diff  \
# 454695 2021-12-24 01:41:03.667334+00:00                    NaT         NaN
# 454448 2021-12-24 01:53:57.197204+00:00 0 days 00:12:53.529870        19.0
# 454207 2021-12-24 02:03:09.197822+00:00 0 days 00:09:12.000618         6.0
# 453955 2021-12-24 02:16:53.157735+00:00 0 days 00:13:43.959913         4.0
# 453707 2021-12-24 06:11:36.043167+00:00 0 days 03:54:42.885432       172.0
# ...                                 ...                    ...         ...
# 12652  2025-08-06 00:03:02.430098+00:00 1 days 00:00:54.740390  11132526.0
# 12518  2025-08-07 00:04:31.258029+00:00 1 days 00:01:28.827931   7255818.0
# 12406  2025-08-08 00:06:04.659983+00:00 1 days 00:01:33.401954   5364151.0
# 12299  2025-08-09 00:04:03.468001+00:00 0 days 23:57:58.808018   2934013.0
# 12208  2025-08-10 00:05:39.790921+00:00 1 days 00:01:36.322920   3612563.0
#
#         like_diff  comment_diff  like_to_view_ratio  view_diff_norm  \
# 454695        NaN           NaN                 NaN             NaN
# 454448        0.0           0.0            0.000000    1.061110e+03
# 454207        0.0           0.0            0.000000    4.695647e+02
# 453955        0.0           0.0            0.000000    2.097189e+02
# 453707        2.0           0.0            0.011628    5.276191e+02
# ...           ...           ...                 ...             ...
# 12652    225526.0         273.0            0.020258    5.562739e+06
# 12518    132420.0          80.0            0.018250    3.624183e+06
# 12406     94910.0         107.0            0.017693    2.679179e+06
# 12299     56149.0          84.0            0.019137    1.469067e+06
# 12208     69681.0          73.0            0.019289    1.804270e+06
#
#         like_diff_norm  like_ratio_norm
# 454695             NaN              NaN
# 454448        0.000000         0.000000
# 454207        0.000000         0.000000
# 453955        0.000000         0.000000
# 453707        6.135106         0.011628
# ...                ...              ...
# 12652    112691.602057         0.020258
# 12518     66141.999341         0.018250
# 12406     47403.754591         0.017693
# 12299     28113.934994         0.019137
# 12208     34801.701372         0.019289
#
# [450889 rows x 34 columns]

# %%
df['duration_seconds'].plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.query('duration_seconds > 500')['duration_seconds'].plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_vid = df.sort_values('pull_date', ascending=False).groupby('id').head(1).reset_index(drop=True)

# %%
df_vid['comment_ratio'] = df_vid['commentCount'] / df_vid['viewCount']

# %%
df_vid.query('viewCount > 1_000_000').sort_values('comment_ratio', ascending=False)
# Out:
#               id                                             title  \
# 847  TRiF8PdrIP8                 MrBeast6000&#39;s Channel Trailer
# 541  mGIpOtncmSM                    Saying Pewdiepie 100,000 Times
# 820  5J6-5g2alp8                           100,000 SUBSCRIBERS.EXE
# 541  https://i.ytimg.com/vi/mGIpOtncmSM/mqdefault.jpg
# 820  https://i.ytimg.com/vi/5J6-5g2alp8/mqdefault.jpg
# 585  https://i.ytimg.com/vi/v1ELS84GQu8/mqdefault.jpg
# 720  https://i.ytimg.com/vi/fG1N5kzeAhM/mqdefault.jpg
# ..                                                ...
# 361  https://i.ytimg.com/vi/k194wHZHjB0/mqdefault.jpg
# 368  https://i.ytimg.com/vi/qtWqHIx8Z-o/mqdefault.jpg
# 363  https://i.ytimg.com/vi/vXNtju4VFm4/mqdefault.jpg
# 350  https://i.ytimg.com/vi/I9mw5UlDyPI/mqdefault.jpg
# 358  https://i.ytimg.com/vi/7K-yxGWYsnk/mqdefault.jpg
#
#      thumbnails.medium.width  thumbnails.medium.height  \
# 847                    320.0                     180.0
# 541                    320.0                     180.0
# 820                    320.0                     180.0
# 585                    320.0                     180.0
# 720                    320.0                     180.0
# ..                       ...                       ...
# 361                    320.0                     180.0
# 368                    320.0                     180.0
# 363                    320.0                     180.0
# 350                    320.0                     180.0
# 358                    320.0                     180.0
#
#                                   thumbnails.high.url  thumbnails.high.width  \
# 847  https://i.ytimg.com/vi/TRiF8PdrIP8/hqdefault.jpg                  480.0
# 541  https://i.ytimg.com/vi/mGIpOtncmSM/hqdefault.jpg                  480.0
# 820  https://i.ytimg.com/vi/5J6-5g2alp8/hqdefault.jpg                  480.0
# 585  https://i.ytimg.com/vi/v1ELS84GQu8/hqdefault.jpg                  480.0
# 720  https://i.ytimg.com/vi/fG1N5kzeAhM/hqdefault.jpg                  480.0
# ..                                                ...                    ...
# 361  https://i.ytimg.com/vi/k194wHZHjB0/hqdefault.jpg                  480.0
# 368  https://i.ytimg.com/vi/qtWqHIx8Z-o/hqdefault.jpg                  480.0
# 363  https://i.ytimg.com/vi/vXNtju4VFm4/hqdefault.jpg                  480.0
# 350  https://i.ytimg.com/vi/I9mw5UlDyPI/hqdefault.jpg                  480.0
# 358  https://i.ytimg.com/vi/7K-yxGWYsnk/hqdefault.jpg                  480.0
#
#      thumbnails.high.height contentDetails.duration contentDetails.dimension  \
# 847                   360.0                 PT1M55S                       2d
# 541                   360.0             PT11H48M40S                       2d
# 820                   360.0                 PT4M26S                       2d
# 585                   360.0                   PT46S                       2d
# 720                   360.0                 PT2M25S                       2d
# ..                      ...                     ...                      ...
# 361                   360.0                   PT22S                       2d
# 368                   360.0                   PT48S                       2d
# 363                   360.0                   PT36S                       2d
# 350                   360.0                   PT19S                       2d
# 358                   360.0                   PT40S                       2d
#
#                           topicDetails.topicCategories  \
# 847                                                NaN
# 541                                                NaN
# 820  ['https://en.wikipedia.org/wiki/Video_game_cul...
# 585                                                NaN
# 720                                                NaN
# ..                                                 ...
# 361  ['https://en.wikipedia.org/wiki/Hobby', 'https...
# 368  ['https://en.wikipedia.org/wiki/Entertainment'...
# 363    ['https://en.wikipedia.org/wiki/Entertainment']
# 350    ['https://en.wikipedia.org/wiki/Entertainment']
# 358  ['https://en.wikipedia.org/wiki/Entertainment'...
#
#     snippet.defaultLanguage             localizations.en.title  \
# 847                     NaN                                NaN
# 541                     NaN                                NaN
# 820                     NaN                                NaN
# 585                     NaN                                NaN
# 720                     NaN                                NaN
# ..                      ...                                ...
# 361                     NaN                                NaN
# 368                      en  Last Person Standing Wins $10,000
# 363                     NaN                                NaN
# 350                      en               This Game Is Wild...
# 358                      en         $10,000 Human Shuffleboard
#
#     localizations.en.description  \
# 847                          NaN
# 541                          NaN
# 820                          NaN
# 585                          NaN
# 720                          NaN
# ..                           ...
# 361                          NaN
# 368                          NaN
# 363                          NaN
# 350                          NaN
# 358                          NaN
#
#                                           snippet.tags  \
# 847                        ['Mr.Beast', 'mr', 'beast']
# 541                                                NaN
# 820  ['100000 subscribers', '100k subs', 'one hundr...
# 585                                                NaN
# 720                        ['Mr.Beast', 'mr', 'beast']
# ..                                                 ...
# 361                                                NaN
# 368                                                NaN
# 363                                                NaN
# 350                                                NaN
# 358                                                NaN
#
#                            pull_date    time_since_last_pull  view_diff  \
# 847 2024-07-19 00:09:23.657625+00:00  0 days 23:58:29.632152      289.0
# 541 2025-05-02 00:10:08.821562+00:00  3 days 00:06:25.265704     1815.0
# 820 2024-08-27 00:08:15.885955+00:00 19 days 00:00:05.909772     7122.0
# 585 2025-04-29 00:03:43.555858+00:00  1 days 00:00:34.404358      579.0
# 720 2025-02-13 00:02:01.489061+00:00  0 days 23:59:28.775447      370.0
# ..                               ...                     ...        ...
# 361 2025-06-08 00:07:05.311499+00:00  1 days 00:05:18.074506   973023.0
# 368 2025-06-08 00:07:05.311499+00:00  1 days 00:05:18.074506  2249765.0
# 363 2025-06-08 00:07:05.311499+00:00  1 days 00:05:18.074506  1383594.0
# 350 2025-06-08 00:07:05.311499+00:00  1 days 00:05:18.074506  1181774.0
# 358 2025-06-08 00:07:05.311499+00:00  1 days 00:05:18.074506  3321266.0
#
#      like_diff  comment_diff  like_to_view_ratio  view_diff_norm  \
# 847        5.0           1.0            0.017301    1.446513e+02
# 541      -70.0          -9.0           -0.038567    3.020510e+02
# 820      156.0        -166.0            0.021904    1.874204e+02
# 585      -18.0          -1.0           -0.031088    2.893848e+02
# 720        9.0           0.0            0.024324    1.850669e+02
# ..         ...           ...                 ...             ...
# 361     6950.0           7.0            0.007143    4.847270e+05
# 368    23345.0          15.0            0.010377    1.120757e+06
# 363    11916.0           0.0            0.008612    6.892595e+05
# 350     7881.0           5.0            0.006669    5.887197e+05
# 358    34720.0          11.0            0.010454    1.654542e+06
#
#      like_diff_norm  like_ratio_norm  comment_ratio
# 847        2.502618         0.017301       0.008280
# 541      -11.649351        -0.038567       0.006304
# 820        4.105248         0.021904       0.005479
# 585       -8.996418        -0.031088       0.005470
# 720        4.501627         0.024324       0.005307
# ..              ...              ...            ...
# 361     3462.253996         0.007143       0.000019
# 368    11629.686265         0.010377       0.000018
# 363     5936.146564         0.008612       0.000014
# 350     3926.046582         0.006669       0.000014
# 358    17296.325000         0.010454       0.000014
#
# [575 rows x 35 columns]
